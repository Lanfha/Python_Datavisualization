# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt

# %%
coviddata = pd.read_csv('C:\\Users\\HP\\OneDrive\\Desktop\\2019_nCoV_data.csv', index_col= 'Sno')

# %%
df = pd.DataFrame(coviddata)

# %%
df
# Out:
#                  Date        Province/State         Country  \
# Sno
# 1     1/22/2020 12:00                 Anhui           China
# 2     1/22/2020 12:00               Beijing           China
# 3     1/22/2020 12:00             Chongqing           China
# 4     1/22/2020 12:00                Fujian           China
# 5     1/22/2020 12:00                 Gansu           China
# 6     1/22/2020 12:00             Guangdong           China
# 7     1/22/2020 12:00               Guangxi           China
# 8     1/22/2020 12:00               Guizhou           China
# 9     1/22/2020 12:00                Hainan           China
# 10    1/22/2020 12:00                 Hebei           China
# 11    1/22/2020 12:00          Heilongjiang           China
# 12    1/22/2020 12:00                 Henan           China
# 13    1/22/2020 12:00             Hong Kong           China
# 14    1/22/2020 12:00                 Hubei           China
# ...

# %%
df.isnull().any()
# Out:
# Date              False
# Province/State     True
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
df["Province/State"].fillna("not mentionned", inplace = True)  
  
df
# Out:
#                  Date        Province/State         Country  \
# Sno
# 1     1/22/2020 12:00                 Anhui           China
# 2     1/22/2020 12:00               Beijing           China
# 3     1/22/2020 12:00             Chongqing           China
# 4     1/22/2020 12:00                Fujian           China
# 5     1/22/2020 12:00                 Gansu           China
# 6     1/22/2020 12:00             Guangdong           China
# 7     1/22/2020 12:00               Guangxi           China
# 8     1/22/2020 12:00               Guizhou           China
# 9     1/22/2020 12:00                Hainan           China
# 10    1/22/2020 12:00                 Hebei           China
# 11    1/22/2020 12:00          Heilongjiang           China
# 12    1/22/2020 12:00                 Henan           China
# 13    1/22/2020 12:00             Hong Kong           China
# 14    1/22/2020 12:00                 Hubei           China
# ...
