# %%
import pandas as pd

# %% [markdown]
# ## Define path to table files

# %%
w_resterant_PATH = 'D:\\w_restaurant.csv'
search_click_PATH = 'D:\\search_click.csv'

# %% [markdown]
# ## load files into memory

# %%
w_resturant_df = pd.read_csv(w_resterant_PATH)
search_click_df = pd.read_csv(search_click_PATH)

# %%
w_resturant_df
# Out:
#             id                                  name  domain_id  closed  \
# 0            2                      นครินทร์ทันตกรรม          2       0
# 1            4                          Corner House          1       0
# 2            5                        วัดโลกยสุธาราม          4       0
# 3            6                        นันท์คาราโอเกะ          1       0
# 4            7                           Buono Caffe          1       0
# 5           14                           บ้านมุมสบาย          1       0
# 6           15                   Hing Fat Resteurant          1       0
# 7           16                              Sazanami          1       0
# 8           20                          ครัวทิพวัลย์          1       0
# 9           21                          นกน้ำเต้าหู้          1       0
# 10          24                        Rotee Me Chabu          1       0
# 11          27                       แพอาหารธาราบุรี          1       0
# ...

# %%
search_click_df.head()
# Out:
#   click_timestamp                             search_id  business_id  \
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
#
#    display_position  time_diff_nanos   ads
# 0                 0     2.222400e+15  True
# 1                 0     4.608380e+14  True
# 2                 0     2.581490e+15  True
# 3                 1     1.404580e+15  True
# 4                 1     9.333590e+14  True

# %%
search_click_df.tail()
# Out:
#         click_timestamp                             search_id  business_id  \
# 1048570         05:28.8  99aab616-6fc5-4fbf-994b-4aebee7bb360     278479.0
# 1048571         15:28.8  d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a     321885.0
# 1048572         11:49.4  4c1de7fe-300e-41aa-9d01-914344fc3753     221035.0
# 1048573         10:33.7  2ec0ddec-e450-4b98-9779-42b77aa7eda5     220572.0
# 1048574         13:51.4  5741d9cf-b9f1-441d-aa83-d2b0179bf874     310448.0
#
#          display_position  time_diff_nanos    ads
# 1048570                 8     2.072630e+11  False
# 1048571                 8     6.931413e+10  False
# 1048572                 8     3.105162e+10  False
# 1048573                 8     7.848904e+10  False
# 1048574                 8     3.157757e+10  False

# %%
search_click_df.shape
# Out:
# (1048575, 6)

# %% [markdown]
# # data preprocessing

# %% [markdown]
# ## missing

# %%
search_click_df.isnull()
# Out:
#          click_timestamp  search_id  business_id  display_position  \
# 0                  False      False        False             False
# 1                  False      False        False             False
# 2                  False      False        False             False
# 3                  False      False        False             False
# 4                  False      False        False             False
# 5                  False      False        False             False
# 6                  False      False        False             False
# 7                  False      False        False             False
# 8                  False      False        False             False
# 9                  False      False        False             False
# 10                 False      False        False             False
# 11                 False      False        False             False
# 12                 False      False        False             False
# ...

# %%
search_click_df.isnull().any()
# Out:
# click_timestamp     False
# search_id            True
# business_id          True
# display_position    False
# time_diff_nanos     False
# ads                 False
# dtype: bool

# %%
w_resturant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %% [markdown]
# ## delete row with missing value

# %%
w_resturant_df.dropna(subset = ['zipcode','number_of_chains'])
# Out:
#             id                                name  domain_id  closed  \
# 61         114                            มานีมีนม          1       0
# 114        224                        สเต็กลุงหนวด          1       0
# 115        225                            Mr.shake          1       0
# 131        267                                 KFC          1       0
# 140        297                          Miss Mamon          1       1
# 149        344                     Inthanin Coffee          1       0
# 194        429                     The Skin Clinic          2       0
# 235        486                                 S&P          1       0
# 243        501                         Holy Shrimp          1       0
# 268        544                      Dunkin' Donuts          1       0
# 316        613        take care beauty salon & spa          2       0
# 325        623                               ดอยคำ          1       0
# ...

# %%
w_resturant_df = w_resturant_df.dropna(subset = ['zipcode','number_of_chains'])

# %% [markdown]
# ## fill default value to the data

# %%
w_resturant_df['parking'].fillna(0)
# Out:
# 61        3.0
# 114       3.0
# 115       0.0
# 131       3.0
# 140       3.0
# 149       3.0
# 194       3.0
# 235       3.0
# 243       3.0
# 268       3.0
# 316       3.0
# 325       0.0
# 382       1.0
# 394       3.0
# 411       3.0
# 437       3.0
# 448       3.0
# 481       0.0
# 556       0.0
# 591       3.0
# 594       3.0
# 608       3.0
# 609       3.0
# 615       0.0
# 624       3.0
# 637       0.0
# 653       0.0
# 678       0.0
# 691       0.0
# 694       3.0
#          ...
# 246311    0.0
# 246312    0.0
# 246333    3.0
# 246365    0.0
# 246386    3.0
# 246407    3.0
# 246425    3.0
# 246454    3.0
# 246458    3.0
# 246460    3.0
# 246466    3.0
# 246477    3.0
# 246490    3.0
# 246508    3.0
# 246528    3.0
# 246533    1.0
# 246550    0.0
# 246561    3.0
# 246586    0.0
# 246614    0.0
# 246619    0.0
# 246620    3.0
# 246646    3.0
# 246680    0.0
# 246684    3.0
# 246722    1.0
# 246752    3.0
# 246815    3.0
# 246834    0.0
# 246842    3.0
# ...

# %%
w_resturant_df['parking'] = w_resturant_df['parking'].fillna(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # select part of the table by value

# %% [markdown]
# ## part of table = table[data_condition == True]

# %%
w_resturant_df['parking'] > 5
# Out:
# 61        False
# 114       False
# 115       False
# 131       False
# 140       False
# 149       False
# 194       False
# 235       False
# 243       False
# 268       False
# 316       False
# 325       False
# 382       False
# 394       False
# 411       False
# 437       False
# 448       False
# 481       False
# 556       False
# 591       False
# 594       False
# 608       False
# 609       False
# 615       False
# 624       False
# 637       False
# 653       False
# 678       False
# 691       False
# 694       False
#           ...
# 246311    False
# 246312    False
# 246333    False
# 246365    False
# 246386    False
# 246407    False
# 246425    False
# 246454    False
# 246458    False
# 246460    False
# 246466    False
# 246477    False
# 246490    False
# 246508    False
# 246528    False
# 246533    False
# 246550    False
# 246561    False
# 246586    False
# 246614    False
# 246619    False
# 246620    False
# 246646    False
# 246680    False
# ...

# %%
w_resturant_df[w_resturant_df['parking'] >= 3]
# Out:
#             id                                name  domain_id  closed  \
# 61         114                            มานีมีนม          1       0
# 114        224                        สเต็กลุงหนวด          1       0
# 131        267                                 KFC          1       0
# 140        297                          Miss Mamon          1       1
# 149        344                     Inthanin Coffee          1       0
# 194        429                     The Skin Clinic          2       0
# 235        486                                 S&P          1       0
# 243        501                         Holy Shrimp          1       0
# 268        544                      Dunkin' Donuts          1       0
# 316        613        take care beauty salon & spa          2       0
# 394        717                             Hongmin          1       0
# 411        739                      MK Restaurants          1       0
# ...

# %% [markdown]
# # HW select all resturants from your hometown

# %%
w_resturant_df = pd.read_csv(w_resterant_PATH)

# %%
w_resturant_df['city_name'] = 'Khon Kaen'

# %%
w_resturant_df[w_resturant_df['city_name']=='Khon Kaen']
# Out:
#             id                                  name  domain_id  closed  \
# 0            2                      นครินทร์ทันตกรรม          2       0
# 1            4                          Corner House          1       0
# 2            5                        วัดโลกยสุธาราม          4       0
# 3            6                        นันท์คาราโอเกะ          1       0
# 4            7                           Buono Caffe          1       0
# 5           14                           บ้านมุมสบาย          1       0
# 6           15                   Hing Fat Resteurant          1       0
# 7           16                              Sazanami          1       0
# 8           20                          ครัวทิพวัลย์          1       0
# 9           21                          นกน้ำเต้าหู้          1       0
# 10          24                        Rotee Me Chabu          1       0
# 11          27                       แพอาหารธาราบุรี          1       0
# ...

# %% [markdown]
# ## save table to a file

# %%
w_resturant
