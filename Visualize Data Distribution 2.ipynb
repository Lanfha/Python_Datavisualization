# %% [markdown]
# ### Box plot

# %%
import pandas
import matplotlib.pyplot as plt

# %%
irisdata = pandas.read_csv('C:\\python\\python_dataviz\\iris.data',header = None)
irisdata.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
setoda_np = irisdata.iloc[:50,:-1].to_numpy()
versicolor_np = irisdata.iloc[50:100,:-1].to_numpy()
virginica_np = irisdata.iloc[100:,:-1].to_numpy()

# %%
setosa_np = irisdata.iloc[:50,:-1].to_numpy()
versicolor_np = irisdata.iloc[50:100,:-1].to_numpy()
c = irisdata.iloc[100:,:-1].to_numpy()


plt.boxplot(setosa_np)


plt.rcParams['figure.figsize']=[12,18]
plt.subplot(1,4,1)
plt.boxplot(setosa_np[:,0])
plt.subplot(1,4,2)
plt.boxplot(setosa_np[:,1])
plt.subplot(1,4,3)
plt.boxplot(setosa_np[:,2])
plt.subplot(1,4,4)
plt.boxplot(setosa_np[:,3])

plt.show()

# %%
import seaborn as sns

# %%
irisdata.head(10)
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa
# 6  4.6  3.4  1.4  0.3  Iris-setosa
# 7  5.0  3.4  1.5  0.2  Iris-setosa
# 8  4.4  2.9  1.4  0.2  Iris-setosa
# 9  4.9  3.1  1.5  0.1  Iris-setosa

# %%
plt.boxplot(setosa_np);

# %% [markdown]
# ### HW

# %% [markdown]
# use boxplot to compare features between 3 classes

# %%
import numpy as np
f1 = [setosa_np[:,0],versicolor_np[:,0],virginica_np[:,0]]

# %%
f1
# Out:
# [array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#         4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#         5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#         5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. ]),
#  array([7. , 6.4, 6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. ,
#         6.1, 5.6, 6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6,
#         6.8, 6.7, 6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6,
#         5.5, 5.5, 6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7]),
#  array([6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8,
#         5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2,
#         6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. ,
#         6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])]

# %%
plt.boxplot(f1,labels=['setosa','versicolor','virginica'])
plt.title('Feature 1 Comparision')
# Out:
# Text(0.5, 1.0, 'Feature 1 Comparision')

# %% [markdown]
# ## bubble chart
# ### คือการใช้ขนาดของวงกลมแสดงค่าของdata

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=1000*setosa_np[1:,2], c = 'G',alpha = 0.2)

# %% [markdown]
# ### MAP

# %%
import pandas

# %%
Debt = 'C:\\Users\\HP\\OneDrive\\Desktop\\Average Debt.xls'

# %%
Debt_df = pandas.read_excel(Debt)

# %%
Debt_df = pandas.read_excel(Debt,skiprows=3)

# %%
Debt_df
# Out:
#             ภาค และจังหวัด                                         Unnamed: 1  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2          ทั่วราชอาณาจักร                                                NaN
# 3                 ตอนพิเศษ                                                NaN
# 4            กรุงเทพมหานคร                                                NaN
# 5              สมุทรปราการ                                                NaN
# 6                  นนทบุรี                                                NaN
# 7                 ปทุมธานี                                                NaN
# 8                  ภาคกลาง                                                NaN
# 9          พระนครศรีอยุธยา                                                NaN
# 10                 อ่างทอง                                                NaN
# 11                  ลพบุรี                                                NaN
# 12               สิงห์บุรี                                                NaN
# 13                  ชัยนาท                                                NaN
# 14                 สระบุรี                                                NaN
# 15                  ชลบุรี                                                NaN
# 16                   ระยอง                                                NaN
# 17                จันทบุรี                                                NaN
# 18                    ตราด                                                NaN
# 19              ฉะเชิงเทรา                                                NaN
# 20              ปราจีนบุรี                                                NaN
# 21                 นครนายก                                                NaN
# 22                 สระแก้ว                                                NaN
# 23                 ราชบุรี                                                NaN
# 24               กาญจนบุรี                                                NaN
# 25              สุพรรณบุรี                                                NaN
# 26                  นครปฐม                                                NaN
# 27               สมุทรสาคร                                                NaN
# 28             สมุทรสงคราม                                                NaN
# 29                เพชรบุรี                                                NaN
# ..                     ...                                                ...
# 59             หนองบัวลำภู                                                NaN
# 60                 ขอนแก่น                                                NaN
# 61                อุดรธานี                                                NaN
# 62                     เลย                                                NaN
# 63                 หนองคาย                                                NaN
# 64               มหาสารคาม                                                NaN
# 65                ร้อยเอ็ด                                                NaN
# 66               กาฬสินธุ์                                                NaN
# 67                  สกลนคร                                                NaN
# 68                  นครพนม                                                NaN
# 69                มุกดาหาร                                                NaN
# 70                  ภาคใต้                                                NaN
# 71           นครศรีธรรมราช                                                NaN
# 72                  กระบี่                                                NaN
# 73                   พังงา                                                NaN
# 74                  ภูเก็ต                                                NaN
# 75            สุราษฎร์ธานี                                                NaN
# 76                   ระนอง                                                NaN
# 77                   ชุมพร                                                NaN
# 78                   สงขลา                                                NaN
# 79                    สตูล                                                NaN
# 80                    ตรัง                                                NaN
# 81                  พัทลุง                                                NaN
# 82                 ปัตตานี                                                NaN
# 83                    ยะลา                                                NaN
# 84                นราธิวาส                                                NaN
# 85                     NaN                                                NaN
# 86                     NaN                                                NaN
# 87                  ที่มา:  การสำรวจภาวะเศรษฐกิจและสังคมของครัวเรือน  สำนั...
# 88                 Source:  The Household Socio - Economic Survey, Nationa...
#
#         2541      2543      2545      2547      2549      2550      2552  \
# 0     1998.0    2000.0    2002.0    2004.0    2006.0    2007.0    2009.0
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 
# 67  138724.7  157855.0  164189.700000                         Sakon Nakhon
# 68   76337.8   90411.0  102816.000000                        Nakhon Phanom
# 69  182410.8  123125.4  184066.900000                             Mukdahan
# 70  110722.7  139931.0  163892.130350                      Southern Region
# 71   89624.8  123677.8  164476.100000                  Nakhon Si Thammarat
# 72  177494.6  168945.8  373325.200000                                Krabi
# 73   82727.7  123375.6  164166.600000                             Phangnga
# 74   71828.9   91903.8  135375.900000                               Phuket
# 75  144725.2  198998.1  219064.900000                          Surat Thani
# 76  161419.6  180868.7  106994.400000                               Ranong
# 77  130163.6  197458.5  199745.900000                             Chumphon
# 78  107471.9  161526.0  172272.100000                             Songkhla
# 79  101355.4  155314.4  145458.000000                                Satun
# 80  154678.4  160207.0  131872.600000                                Trang
# 81  169818.7  162248.7  206986.400000                           Phattalung
# 82   83776.5  109102.5  141540.100000                              Pattani
# 83   60166.7   35828.9   22272.400000                                 Yala
# 84   40942.5   44974.1   40566.900000                           Narathiwat
# 85       NaN       NaN            NaN                                  NaN
# 86       NaN       NaN            NaN                                  NaN
# 87       NaN       NaN            NaN                                  NaN
# 88       NaN       NaN            NaN                                  NaN
#
# [89 rows x 13 columns]

# %%
Debt_df[['Region and province',2549]]
# Out:
#                     Region and province      2549
# 0                                   NaN    2006.0
# 1                                   NaN       NaN
# 2                         Whole Kingdom  116585.0
# 3                       Greater Bangkok  155212.0
# 4                               Bangkok  158059.0
# 5                          Samut Prakan   95975.0
# 6                            Nonthaburi  179007.0
# 7                          Pathum Thani  193153.0
# 8                        Central Region  113475.0
# 9              Phra Nakhon Si Ayutthaya   53222.0
# 10                            Ang Thong  118556.0
# 11                             Lop Buri  162620.0
# 12                            Sing Buri   88518.0
# 13                             Chai Nat   98121.0
# 14                             Saraburi  111111.0
# 15                            Chon Buri  128114.0
# 16                               Rayong  114145.0
# 17                          Chanthaburi  176403.0
# 18                                 Trat   90976.0
# 19                         Chachoengsao   77611.0
# 20                         Prachin Buri   96975.0
# 21                         Nakhon Nayok   96838.0
# 22                              Sa Kaeo   88116.0
# 23                           Ratchaburi  110017.0
# 24                         Kanchanaburi  114158.0
# 25                          Suphan Buri   93851.0
# 26                        Nakhon Pathom  167798.0
# 27                         Samut Sakhon  138320.0
# 28                      Samut Songkhram    8411.0
# 29                          Phetchaburi   85158.0
# ..                                  ...       ...
# 59                     Nong Bua Lam Phu  108075.0
# 60                            Khon Kaen   80653.0
# 61                           Udon Thani   97136.0
# 62                                 Loei  118555.0
# 63                            Nong Khai  109812.0
# 64                        Maha Sarakham  109654.0
# 65                               Roi Et  109546.0
# 66                              Kalasin  109921.0
# 67                         Sakon Nakhon   96367.0
# 68                        Nakhon Phanom   85741.0
# 69                             Mukdahan  132063.0
# 70                      Southern Region  114179.0
# 71                  Nakhon Si Thammarat  107541.0
# 72                                Krabi  156798.0
# 73                             Phangnga   87955.0
# 74                               Phuket   72379.0
# 75                          Surat Thani  125727.0
# 76                               Ranong   92274.0
# 77                             Chumphon  116327.0
# 78                             Songkhla  174109.0
# 79                                Satun   69314.0
# 80                                Trang  133375.0
# 81                           Phattalung  117631.0
# 82                              Pattani   82046.0
# 83                                 Yala   55672.0
# 84                           Narathiwat   57235.0
# 85                                  NaN       NaN
# 86                                  NaN       NaN
# 87                                  NaN       NaN
# 88                                  NaN       NaN
#
# [89 rows x 2 columns]

# %%
Debt_df_debt=Debt_df[['Region and province',2549]]

# %%
Debt_df_debt.drop([0,1,2,3,8,31,49,70,85,86,87,88],axis=0,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
Debt_df_debt
# Out:
#                     Region and province      2549
# 4                               Bangkok  158059.0
# 5                          Samut Prakan   95975.0
# 6                            Nonthaburi  179007.0
# 7                          Pathum Thani  193153.0
# 9              Phra Nakhon Si Ayutthaya   53222.0
# 10                            Ang Thong  118556.0
# 11                             Lop Buri  162620.0
# 12                            Sing Buri   88518.0
# 13                             Chai Nat   98121.0
# 14                             Saraburi  111111.0
# 15                            Chon Buri  128114.0
# 16                               Rayong  114145.0
# 17                          Chanthaburi  176403.0
# 18                                 Trat   90976.0
# 19                         Chachoengsao   77611.0
# 20                         Prachin Buri   96975.0
# 21                         Nakhon Nayok   96838.0
# 22                              Sa Kaeo   88116.0
# 23                           Ratchaburi  110017.0
# 24                         Kanchanaburi  114158.0
# 25                          Suphan Buri   93851.0
# 26                        Nakhon Pathom  167798.0
# 27                         Samut Sakhon  138320.0
# 28                      Samut Songkhram    8411.0
# 29                          Phetchaburi   85158.0
# 30                  Prachuap Khiri Khan  128589.0
# 32                           Chiang Mai  114321.0
# 33                              Lamphun  119570.0
# 34                              Lampang  152660.0
# 35                            Uttaradit  125520.0
# ..                                  ...       ...
# 54                     Ubon Ratchathani   95706.0
# 55                             Yasothon   78766.0
# 56                           Chaiyaphum   96854.0
# 57                        Amnat Charoen   96400.0
# 58                              Bungkan       NaN
# 59                     Nong Bua Lam Phu  108075.0
# 60                            Khon Kaen   80653.0
# 61                           Udon Thani   97136.0
# 62                                 Loei  118555.0
# 63                            Nong Khai  109812.0
# 64                        Maha Sarakham  109654.0
# 65                               Roi Et  109546.0
# 66                              Kalasin  109921.0
# 67                         Sakon Nakhon   96367.0
# 68                        Nakhon Phanom   85741.0
# 69                             Mukdahan  132063.0
# 71                  Nakhon Si Thammarat  107541.0
# 72                                Krabi  156798.0
# 73                             Phangnga   87955.0
# 74                               Phuket   72379.0
# 75                          Surat Thani  125727.0
# 76                               Ranong   92274.0
# 77                             Chumphon  116327.0
# 78                             Songkhla  174109.0
# 79                                Satun   69314.0
# 80                                Trang  133375.0
# 81                           Phattalung  117631.0
# 82                              Pattani   82046.0
# 83                                 Yala   55672.0
# 84                           Narathiwat   57235.0
#
# [77 rows x 2 columns]

# %%
Debt_df_debt.head()
# Out:
#                    Region and province      2549
# 4                              Bangkok  158059.0
# 5                         Samut Prakan   95975.0
# 6                           Nonthaburi  179007.0
# 7                         Pathum Thani  193153.0
# 9             Phra Nakhon Si Ayutthaya   53222.0

# %%
# !pip install folium
import pandas as pd
import folium
# Out:
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.10.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.16.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)

# %%
data_to_plot = Debt_df_debt

# %%
data_to_plot
# Out:
#                     Region and province      2549
# 4                               Bangkok  158059.0
# 5                          Samut Prakan   95975.0
# 6                            Nonthaburi  179007.0
# 7                          Pathum Thani  193153.0
# 9              Phra Nakhon Si Ayutthaya   53222.0
# 10                            Ang Thong  118556.0
# 11                             Lop Buri  162620.0
# 12                            Sing Buri   88518.0
# 13                             Chai Nat   98121.0
# 14                             Saraburi  111111.0
# 15                            Chon Buri  128114.0
# 16                               Rayong  114145.0
# 17                          Chanthaburi  176403.0
# 18                                 Trat   90976.0
# 19                         Chachoengsao   77611.0
# 20                         Prachin Buri   96975.0
# 21                         Nakhon Nayok   96838.0
# 22                              Sa Kaeo   88116.0
# 23                           Ratchaburi  110017.0
# 24                         Kanchanaburi  114158.0
# 25                          Suphan Buri   93851.0
# 26                        Nakhon Pathom  167798.0
# 27                         Samut Sakhon  138320.0
# 28                      Samut Songkhram    8411.0
# 29                          Phetchaburi   85158.0
# 30                  Prachuap Khiri Khan  128589.0
# 32                           Chiang Mai  114321.0
# 33                              Lamphun  119570.0
# 34                              Lampang  152660.0
# 35                            Uttaradit  125520.0
# ..                                  ...       ...
# 54                     Ubon Ratchathani   95706.0
# 55                             Yasothon   78766.0
# 56                           Chaiyaphum   96854.0
# 57                        Amnat Charoen   96400.0
# 58                              Bungkan       NaN
# 59                     Nong Bua Lam Phu  108075.0
# 60                            Khon Kaen   80653.0
# 61                           Udon Thani   97136.0
# 62                                 Loei  118555.0
# 63                            Nong Khai  109812.0
# 64                        Maha Sarakham  109654.0
# 65                               Roi Et  109546.0
# 66                              Kalasin  109921.0
# 67                         Sakon Nakhon   96367.0
# 68                        Nakhon Phanom   85741.0
# 69                             Mukdahan  132063.0
# 71                  Nakhon Si Thammarat  107541.0
# 72                                Krabi  156798.0
# 73                             Phangnga   87955.0
# 74                               Phuket   72379.0
# 75                          Surat Thani  125727.0
# 76                               Ranong   92274.0
# 77                             Chumphon  116327.0
# 78                             Songkhla  174109.0
# 79                                Satun   69314.0
# 80                                Trang  133375.0
# 81                           Phattalung  117631.0
# 82                              Pattani   82046.0
# 83                                 Yala   55672.0
# 84                           Narathiwat   57235.0
#
# [77 rows x 2 columns]

# %%
data_to_plot.head()
# Out:
#                    Region and province      2549
# 4                              Bangkok  158059.0
# 5                         Samut Prakan   95975.0
# 6                           Nonthaburi  179007.0
# 7                         Pathum Thani  193153.0
# 9             Phra Nakhon Si Ayutthaya   53222.0

# %%
country_geo = 'C:\\Users\\HP\\OneDrive\\Desktop\\thai.json'

# %%
new_col=list()
for d in data_to_plot['Region and province']:
    new_col.append(d.lstrip())
data_to_plot['Region and province']=new_col
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
map = folium.Map(location=[10,100], zoom_start=5)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.choropleth(geo_data=country_geo, data=data_to_plot,
             columns=['Region and province', 2549],
             key_on='feature.properties.name',
             fill_color='YlGnBu',fill_opacity=0.7, line_opacity=0.2,
             legend_name='Average Debt')

# %%
map.save('plot_data.html')

# %%
# Out:
# <ifram src=plot_data.html width=450 height=700></iframe>

# %%
from IPython.display import HTML
HTML('<iframe src=plot_data.html width=450 height=700></iframe>')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py:694: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=plot_data.html width=450 height=700></iframe>
